# %% [markdown]
# #### Import necessery packages

# %%
import numpy as np
from PIL import Image
import random
import cv2
import os
import matplotlib.pyplot as plt

# %% [markdown]
# #### LSB Modification

# %%
from PIL import Image

def set_lsb(pixel_value, lsb_bit):
    cleared_pixel_value = pixel_value & 0b1111111111111110
    # Set the LSB to the desired value
    modified_pixel_value = cleared_pixel_value | lsb_bit
    return modified_pixel_value

def manipulate_image_lsb(input_image_path, output_image_path, lsb_value=0):
    print(lsb_value)
    original_image = Image.open(input_image_path)
    image_data = list(original_image.getdata())
    manipulated_data = [set_lsb(pixel_value, lsb_value) for pixel_value in image_data]
    manipulated_image = Image.new(original_image.mode, original_image.size)
    manipulated_image.putdata(manipulated_data)
    manipulated_image.save(output_image_path)

    return manipulated_image
manipulate_image_lsb(r'C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\COVER\2.png', 'output1.png', lsb_value=1) # lsb_value = 0 or 1
# Out:
# 1
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# ##### Apply LSB modification to bunch of images

# %%
import cv2
import numpy as np
import os
from PIL import Image


def MODIFY_img_LSB(input_folder, output_folder):
    all_files = os.listdir(input_folder)
    all_files.sort(key=lambda x: int(os.path.splitext(x)[0].split("_")[0]))
    MODIFIED_LSB = 1
    for filename in all_files:
        file_path = os.path.join(input_folder, filename)
        org_filename = os.path.splitext(filename)[0]     

        MLSB_filename = f"{org_filename}__LSB{MODIFIED_LSB}.png" 
        output_path = os.path.join(output_folder, MLSB_filename)
        
        manipulate_image_lsb(file_path, output_path, MODIFIED_LSB)

    print("Completed")


if __name__ == "__main__":

    # input_folder = "NOISE"  
    input_folder = "COVER"  
    output_folder = "BIT_MNIPULATED" 
    MODIFY_img_LSB(input_folder,output_folder)

# %% [markdown]
# #### Generate rectangles with noise

# %%
def generate_all_combinations(x_values, y_values):
    combinations = [(y, x) for y in y_values for x in x_values]
    return combinations

def Add_White_Noise(image, x, y):
    corners = generate_all_combinations(x, y)
    noise_radius = np.random.randint(0, 3)
    selected_corner = random.choice(corners)
    image_array = np.array(image)
    noise_y, noise_x = np.ogrid[-noise_radius:noise_radius + 1, -noise_radius:noise_radius + 1]
    noise_mask = noise_x**2 + noise_y**2 <= noise_radius**2
    noise_y = np.clip(noise_y + selected_corner[0], 0, 255)
    noise_x = np.clip(noise_x + selected_corner[1], 0, 255)

    try:
        image_array[noise_y, noise_x] = 255
    except IndexError:
        pass
    
    return Image.fromarray(image_array)

def Add_Black_Noise(image, x, y):
    outside_corners = generate_all_combinations(x, y)
    outside_selected_corner = random.choice(outside_corners)
    
    image_array = np.array(image)
    
    noise_radius = np.random.randint(0, 4)
    noise_y, noise_x = np.ogrid[-noise_radius:noise_radius + 1, -noise_radius:noise_radius + 1]
    noise_mask = noise_x**2 + noise_y**2 <= noise_radius**2
    noise_y = np.clip(noise_y + outside_selected_corner[0], 0, 255)
    noise_x = np.clip(noise_x + outside_selected_corner[1], 0, 255)
    
    try:
        image_array[noise_y, noise_x] = 0
    except IndexError:
        pass
    
    return Image.fromarray(image_array)

def add_white_noise(image,top_left_y,bottom_right_y, top_left_x,bottom_right_x):
    num_clusters = np.random.randint(0,5)  # Choose 1 to 2 clusters
    image = np.array(image)
    for _ in range(num_clusters):
        cluster_size = np.random.randint(0, 4)  # Cluster size: 2 to 4 pixels
        cluster_x = np.random.randint(top_left_x, bottom_right_x - cluster_size + 1)
        cluster_y = np.random.randint(top_left_y, bottom_right_y - cluster_size + 1)
        cluster_values = np.random.choice([0, 255], size=(cluster_size, cluster_size))
        image[cluster_y:cluster_y+cluster_size, cluster_x:cluster_x+cluster_size] = cluster_values

    return image

def add_black_noise(image):
    height, width = image.shape
    num_clusters = np.random.randint(0,30)
    for _ in range(num_clusters):
        cluster_size = np.random.randint(0, 4) 
        cluster_x = np.random.randint(0, width - cluster_size + 1)
        cluster_y = np.random.randint(0, height - cluster_size + 1)
        image[cluster_y:cluster_y+cluster_size, cluster_x:cluster_x+cluster_size] = 0

def Add_Round_Corner(image,top_left_y,bottom_right_y, top_left_x,bottom_right_x):
    radius = random.randint(4,10)  
    round_corner = np.random.choice(['top_left', 'top_right', 'bottom_left', 'bottom_right'])
    if round_corner == 'top_left':
        mask = np.zeros_like(image)
        cv2.circle(mask, (top_left_x + radius, top_left_y + radius), radius, 255, thickness=-1)
        image = np.maximum(image, mask)
    elif round_corner == 'top_right':
        mask = np.zeros_like(image)
        cv2.circle(mask, (bottom_right_x - radius, top_left_y + radius), radius, 255, thickness=-1)
        image = np.maximum(image, mask)
    elif round_corner == 'bottom_left':
        mask = np.zeros_like(image)
        cv2.circle(mask, (top_left_x + radius, bottom_right_y - radius), radius, 255, thickness=-1)
        image = np.maximum(image, mask)
    elif round_corner == 'bottom_right':
        mask = np.zeros_like(image)
        cv2.circle(mask, (bottom_right_x - radius, bottom_right_y - radius), radius, 255, thickness=-1)
        image = np.maximum(image, mask)


def Gen_Rects(image, min_size=12, max_size=16, noise_radius=2, ):
    top_left_x, top_left_y = np.random.randint(6, 200, 2)
    max_width = min(max_size, 256 - top_left_x)
    max_height = min(max_size, 256 - top_left_y)
    width = np.random.randint(min_size, max_width + 1)
    height = np.random.randint(min_size, max_height + 1)
    bottom_right_x = top_left_x + width
    bottom_right_y = top_left_y + height
    x = (top_left_x,top_left_x-1,top_left_x+1, bottom_right_x , bottom_right_x - 1, bottom_right_x + 1)
    y = (top_left_y,top_left_y-1,top_left_y+1, bottom_right_y , bottom_right_y - 1, bottom_right_y + 1)
    image[top_left_y:bottom_right_y, top_left_x:bottom_right_x] = 0

    call_function_randomly = random.choice([True,False])
    if call_function_randomly:
        image = add_white_noise(image,top_left_y,bottom_right_y, top_left_x,bottom_right_x)


    call_function_randomly = random.choice([True,False])
    if call_function_randomly:
        image = Add_White_Noise(image,x,y)

    call_function_randomly = random.choice([True,False])
    if call_function_randomly:
        image = Add_Black_Noise(image,x,y)

    return image


def GEN_MUL_Rects(num_rectangles,ORG_name):
    image_size=(256, 256)
    rectangles = []
    for i in range(num_rectangles):
        matrix = np.ones(image_size, dtype=np.uint8) * 255
        matrix = Gen_Rects(matrix, min_size=12, max_size=16)
        rectangles.append(np.array(matrix))
        add_black_noise(rectangles[i])
        
    for i, rect in enumerate(rectangles):
        image = Image.fromarray(rect)
        image.save(f"{ORG_name}__Rects{i + 1}.png")
    return rectangles

# %% [markdown]
# #### Encoder function

# %%
def overlap_and_save_images(rectangles, image_size=(256, 256)):
    final_matrix = np.ones(image_size, dtype=np.uint8) * 255
    for rectangle_matrix in rectangles:
        final_matrix[rectangle_matrix == 0] = 0
    final_image = Image.fromarray(final_matrix)
    return np.array(final_image)


# Encoder 
def Encode_rectangle(image_path, payload):
    original_image = Image.open(image_path)
    secret_array = payload
    original_array = np.array(original_image)
    #-------------- MAIN ENCODER------------------------ 
    if len(secret_array.shape) == 3:
        secret_array = np.mean(secret_array, axis=-1)
        
    for y in range(secret_array.shape[0]):
        for x in range(secret_array.shape[1]):
            original_pixel = original_array[y, x]
            secret_pixel = secret_array[y, x]
            modified_pixel = (original_pixel & 0b1111111111111110) | (secret_pixel & 1)
            original_array[y, x] = modified_pixel

    steganographic_image = Image.fromarray(original_array)
  
    return steganographic_image

# %% [markdown]
# #### Apply encoding on bunch of images

# %%
def HIDE_images(input_folder, Rects_folder, Stego_folder, Stego_folder2):
    all_files = os.listdir(input_folder)
    all_files.sort(key=lambda x: int(os.path.splitext(x)[0].split("_")[0]))

    for filename in all_files:
        file_path = os.path.join(input_folder, filename)
        org_filename = os.path.splitext(filename)[0]     
        print("Working on :", file_path)
        Rects_output_path = os.path.join(Rects_folder, org_filename)
        gen_rects = 3
        rects = GEN_MUL_Rects(gen_rects,Rects_output_path)
        ovrRects = overlap_and_save_images(rects)
        for i in range(5):
            if i < gen_rects:
                encoded_image = Encode_rectangle(file_path,rects[i])
                stego_filename = f"{org_filename}__Rect{i}.png"
                output_path = os.path.join(Stego_folder, stego_filename)
            else :
                encoded_image = Encode_rectangle(file_path,ovrRects)
                stego_filename = f"{org_filename}__OVR_Rect.png" 
                output_path = os.path.join(Stego_folder2, stego_filename)
                
            encoded_image_array = np.array(encoded_image)
            cv2.imwrite(output_path, encoded_image_array )

    print("Completed")


if __name__ == "__main__":

    # input_folder = "TEST"  
    input_folder = r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED"  
    Rects = r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\Rects"
    Stego_folder = r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect" 
    Stego_folder2 = r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect_OVERLAP"
    HIDE_images(input_folder,Rects, Stego_folder, Stego_folder2)
# Out:
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\1__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\2__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\3__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\4__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\5__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\6__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\7__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\8__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\9__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\10__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\11__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\12__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\13__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\14__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\15__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\16__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\17__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\18__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\19__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\20__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\21__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\22__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\23__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\24__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\25__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\26__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\27__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\28__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\29__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\30__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\31__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\32__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\33__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\34__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\35__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\36__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\37__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\38__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\39__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\40__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\41__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\42__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\43__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\44__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\45__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\46__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\47__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\48__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\49__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\50__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\51__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\52__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\53__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\54__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\55__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\56__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\57__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\58__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\59__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\60__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\61__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\62__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\63__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\64__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\65__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\66__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\67__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\68__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\69__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\70__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\71__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\72__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\73__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\74__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\75__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\76__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\77__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\78__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\79__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\80__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\81__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\82__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\83__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\84__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\85__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\86__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\87__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\88__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\89__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\90__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\91__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\92__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\93__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\94__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\95__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\96__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\97__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\98__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\99__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\100__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\101__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\102__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\103__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\104__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\105__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\106__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\107__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\108__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\109__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\110__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\111__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\112__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\113__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\114__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\115__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\116__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\117__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\118__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\119__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\120__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\121__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\122__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\123__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\124__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\125__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\126__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\127__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\128__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\129__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\130__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\131__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\132__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\133__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\134__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\135__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\136__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\137__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\138__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\139__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\140__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\141__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\142__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\143__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\144__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\145__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\146__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\147__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\148__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\149__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\150__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\151__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\152__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\153__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\154__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\155__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\156__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\157__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\158__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\159__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\160__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\161__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\162__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\163__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\164__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\165__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\166__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\167__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\168__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\169__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\170__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\171__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\172__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\173__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\174__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\175__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\176__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\177__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\178__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\179__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\180__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\181__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\182__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\183__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\184__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\185__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\186__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\187__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\188__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\189__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\190__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\191__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\192__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\193__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\194__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\195__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\196__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\197__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\198__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\199__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\200__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\201__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\202__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\203__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\204__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\205__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\206__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\207__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\208__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\209__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\210__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\211__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\212__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\213__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\214__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\215__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\216__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\217__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\218__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\219__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\220__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\221__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\222__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\223__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\224__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\225__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\226__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\227__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\228__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\229__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\230__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\231__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\232__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\233__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\234__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\235__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\236__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\237__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\238__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\239__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\240__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\241__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\242__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\243__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\244__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\245__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\246__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\247__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\248__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\249__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\250__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\251__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\252__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\253__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\254__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\255__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\256__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\257__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\258__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\259__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\260__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\261__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\262__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\263__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\264__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\265__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\266__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\267__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\268__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\269__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\270__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\271__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\272__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\273__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\274__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\275__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\276__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\277__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\278__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\279__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\280__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\281__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\282__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\283__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\284__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\285__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\286__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\287__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\288__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\289__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\290__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\291__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\292__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\293__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\294__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\295__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\296__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\297__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\298__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\299__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\300__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\301__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\302__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\303__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\304__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\305__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\306__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\307__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\308__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\309__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\310__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\311__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\312__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\313__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\314__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\315__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\316__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\317__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\318__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\319__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\320__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\321__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\322__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\323__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\324__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\325__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\326__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\327__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\328__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\329__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\330__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\331__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\332__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\333__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\334__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\335__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\336__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\337__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\338__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\339__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\340__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\341__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\342__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\343__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\344__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\345__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\346__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\347__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\348__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\349__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\350__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\351__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\352__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\353__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\354__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\355__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\356__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\357__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\358__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\359__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\360__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\361__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\362__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\363__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\364__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\365__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\366__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\367__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\368__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\369__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\370__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\371__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\372__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\373__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\374__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\375__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\376__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\377__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\378__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\379__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\380__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\381__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\382__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\383__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\384__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\385__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\386__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\387__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\388__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\389__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\390__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\391__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\392__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\393__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\394__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\395__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\396__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\397__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\398__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\399__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\400__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\401__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\402__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\403__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\404__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\405__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\406__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\407__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\408__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\409__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\410__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\411__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\412__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\413__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\414__LSB1.png
# ...
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\864__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\865__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\866__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\867__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\868__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\869__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\870__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\871__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\872__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\873__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\874__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\875__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\876__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\877__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\878__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\879__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\880__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\881__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\882__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\883__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\884__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\885__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\886__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\887__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\888__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\889__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\890__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\891__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\892__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\893__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\894__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\895__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\896__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\897__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\898__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\899__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\900__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\901__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\902__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\903__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\904__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\905__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\906__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\907__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\908__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\909__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\910__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\911__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\912__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\913__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\914__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\915__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\916__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\917__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\918__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\919__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\920__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\921__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\922__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\923__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\924__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\925__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\926__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\927__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\928__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\929__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\930__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\931__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\932__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\933__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\934__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\935__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\936__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\937__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\938__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\939__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\940__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\941__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\942__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\943__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\944__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\945__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\946__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\947__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\948__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\949__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\950__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\951__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\952__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\953__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\954__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\955__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\956__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\957__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\958__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\959__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\960__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\961__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\962__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\963__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\964__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\965__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\966__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\967__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\968__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\969__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\970__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\971__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\972__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\973__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\974__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\975__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\976__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\977__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\978__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\979__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\980__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\981__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\982__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\983__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\984__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\985__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\986__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\987__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\988__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\989__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\990__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\991__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\992__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\993__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\994__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\995__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\996__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\997__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\998__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\999__LSB1.png
# Working on : C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\1000__LSB1.png
# Completed

# %% [markdown]
# #### Plot output

# %%
img = np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\BIT_MNIPULATED\3__LSB1.png").convert("L"))

image0= np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect\3__LSB1__Rect0.png").convert("L"))
image1= np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect\3__LSB1__Rect1.png").convert("L"))
image2= np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect\3__LSB1__Rect2.png").convert("L"))
image3= np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\NEWDATASET2\STEGO_Rect_OVERLAP\3__LSB1__OVR_Rect.png").convert("L"))

image4 = np.asarray(Image.open(r"C:\Users\shova\OneDrive\Desktop\IEM\SEM3\Project\CREATE_LSB_Stego_dataset\extracted_rectangle.png").convert("L"))

plt.subplot(1, 5, 1 )
plt.imshow(img, cmap='gray')
plt.title('Original ')
plt.axis('off')
plt.subplot(1, 5, 2)
plt.imshow(image0, cmap='gray')
plt.title('Stego 1')
plt.axis('off')
plt.subplot(1, 5, 3)
plt.imshow(image1, cmap='gray')
plt.title('Stego 2')
plt.axis('off')
plt.subplot(1, 5, 4)
plt.imshow(image2, cmap='gray')
plt.title('Stego 3')
plt.axis('off')
plt.subplot(1, 5, 5 )
plt.imshow(image3, cmap='gray')
plt.title('Overlaped')
plt.axis('off')

plt.show()


plt.subplot(2, 5, 1)
plt.imshow(img, cmap='gray')
plt.title('original')
plt.axis('off')
plt.subplot(2, 5, 2)
plt.imshow(image3, cmap='gray')
plt.title('Stego ')
plt.axis('off')
r = img - image3
plt.subplot(2, 5, 3)
plt.imshow(r, cmap='gray')
plt.title('Diff')
plt.axis('off')
s = image4
plt.subplot(2, 5, 4 )
plt.imshow(s, cmap='gray')
plt.title('Retrieved')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Decoder Function

# %%
def decode_rectangle(steganographic_image_path, output_image_path):
    steganographic_image = Image.open(steganographic_image_path)
    steganographic_array = np.array(steganographic_image)
    extracted_rectangle = steganographic_array & 1
    extracted_image = Image.fromarray((extracted_rectangle * 255).astype(np.uint8))
    extracted_image.save(output_image_path)

    
decode_rectangle(r"NEWDATASET2\STEGO_Rect_OVERLAP\3__LSB1__OVR_Rect.png", "extracted_rectangle.png")
